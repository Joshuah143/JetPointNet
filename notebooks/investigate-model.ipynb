# %%
import sys
from pathlib import Path
REPO_PATH = Path.home() / "workspace/jetpointnet"
SCRIPT_PATH = REPO_PATH / "python_scripts"
sys.path.append(str(SCRIPT_PATH))
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""

#from data_processing.jets.preprocessing_header import AWK_SAVE_LOC, MAX_SAMPLE_LENGTH, LEN, MIN_TRACK_POINTS, ROOT_FILES_DIR, LEN_OUTPUT_DIRECTORY_NAME, LEN_DATASET_NAME, prefix_match, prefix_to_set
#from data_processing.jets.jets_max_sample_length import find_global_max_sample_length
from jets_training.models.JetPointNet import PointNetSegmentation

import re
from pathlib import Path
import random
import json
import re
import matplotlib.pyplot as plt
import numpy as np
import uproot
import glob
# Out:
# 2024-07-03 19:12:28.311872: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-03 19:12:28.385025: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9373] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-03 19:12:28.385066: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-03 19:12:28.386897: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1534] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-03 19:12:28.397712: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = PointNetSegmentation(
        num_points=650,
        num_features=7,
        num_classes=1,
        output_activation_function="sigmoid",
    )
# Out:
# 2024-07-03 19:12:31.082956: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-07-03 19:12:31.082995: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:129] retrieving CUDA diagnostic information for host: triumf-ml2
# 2024-07-03 19:12:31.083002: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:136] hostname: triumf-ml2
# 2024-07-03 19:12:31.083063: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:159] libcuda reported version is: INVALID_ARGUMENT: expected %d.%d, %d.%d.%d, or %d.%d.%d.%d form for driver version; got "1"
# 2024-07-03 19:12:31.083090: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] kernel reported version is: 550.67.0

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 650, 7)]             0         []
#
#  lambda (Lambda)             (None, 650)                  0         ['input_1[0][0]']
#
#  lambda_1 (Lambda)           (None, 650)                  0         ['lambda[0][0]']
#
#  lambda_2 (Lambda)           (None, 650, 1)               0         ['lambda_1[0][0]']
#
#  multiply (Multiply)         (None, 650, 7)               0         ['input_1[0][0]',
#                                                                      'lambda_2[0][0]']
#
#  conv1d (Conv1D)             (None, 650, 64)              512       ['multiply[0][0]']
#
#  batch_normalization (Batch  (None, 650, 64)              256       ['conv1d[0][0]']
#  Normalization)
#
#  conv1d_1 (Conv1D)           (None, 650, 128)             8320      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 650, 128)             512       ['conv1d_1[0][0]']
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 650, 1024)            132096    ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 650, 1024)            4096      ['conv1d_2[0][0]']
#  chNormalization)
#
#  global_max_pooling1d (Glob  (None, 1024)                 0         ['batch_normalization_2[0][0]'
#  alMaxPooling1D)                                                    ]
#
#  dense (Dense)               (None, 512)                  524800    ['global_max_pooling1d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 512)                  2048      ['dense[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 512)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, 256)                  131328    ['activation[0][0]']
#
#  batch_normalization_4 (Bat  (None, 256)                  1024      ['dense_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256)                  0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 49)                   12593     ['activation_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, 49)                   196       ['dense_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 49)                   0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  reshape (Reshape)           (None, 7, 7)                 0         ['activation_2[0][0]']
#
#  dot (Dot)                   (None, 650, 7)               0         ['multiply[0][0]',
#                                                                      'reshape[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 650, 96)              768       ['dot[0][0]']
#
#  batch_normalization_6 (Bat  (None, 650, 96)              384       ['conv1d_3[0][0]']
#  chNormalization)
#
#  conv1d_4 (Conv1D)           (None, 650, 96)              9312      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_7 (Bat  (None, 650, 96)              384       ['conv1d_4[0][0]']
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 650, 64)              6208      ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_8 (Bat  (None, 650, 64)              256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  conv1d_6 (Conv1D)           (None, 650, 128)             8320      ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 650, 128)             512       ['conv1d_6[0][0]']
#  chNormalization)
#
#  conv1d_7 (Conv1D)           (None, 650, 1024)            132096    ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  batch_normalization_10 (Ba  (None, 650, 1024)            4096      ['conv1d_7[0][0]']
#  tchNormalization)
#
#  global_max_pooling1d_1 (Gl  (None, 1024)                 0         ['batch_normalization_10[0][0]
#  obalMaxPooling1D)                                                  ']
#
#  dense_3 (Dense)             (None, 512)                  524800    ['global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  batch_normalization_11 (Ba  (None, 512)                  2048      ['dense_3[0][0]']
#  tchNormalization)
#
#  activation_3 (Activation)   (None, 512)                  0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 256)                  131328    ['activation_3[0][0]']
#
#  batch_normalization_12 (Ba  (None, 256)                  1024      ['dense_4[0][0]']
#  tchNormalization)
#
#  activation_4 (Activation)   (None, 256)                  0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 9216)                 2368512   ['activation_4[0][0]']
#
#  batch_normalization_13 (Ba  (None, 9216)                 36864     ['dense_5[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 9216)                 0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  reshape_1 (Reshape)         (None, 96, 96)               0         ['activation_5[0][0]']
#
#  dot_1 (Dot)                 (None, 650, 96)              0         ['batch_normalization_7[0][0]'
#                                                                     , 'reshape_1[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 650, 128)             12416     ['dot_1[0][0]']
#
#  batch_normalization_14 (Ba  (None, 650, 128)             512       ['conv1d_8[0][0]']
#  tchNormalization)
#
#  conv1d_9 (Conv1D)           (None, 650, 256)             33024     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_15 (Ba  (None, 650, 256)             1024      ['conv1d_9[0][0]']
#  tchNormalization)
#
#  conv1d_10 (Conv1D)          (None, 650, 1024)            263168    ['batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 650, 1024)            4096      ['conv1d_10[0][0]']
#  tchNormalization)
#
#  GlobalPooling (GlobalMaxPo  (None, 1024)                 0         ['batch_normalization_16[0][0]
#  oling1D)                                                           ']
#
#  lambda_3 (Lambda)           (None, 1, 1024)              0         ['GlobalPooling[0][0]']
#
#  lambda_4 (Lambda)           (None, 650, 1024)            0         ['lambda_3[0][0]']
#
#  concatenate (Concatenate)   (None, 650, 1120)            0         ['batch_normalization_7[0][0]'
#                                                                     , 'lambda_4[0][0]']
#
#  PostGlobal512 (Conv1D)      (None, 650, 512)             573952    ['concatenate[0][0]']
#
#  batch_normalization_17 (Ba  (None, 650, 512)             2048      ['PostGlobal512[0][0]']
#  tchNormalization)
#
#  PostGlobal256 (Conv1D)      (None, 650, 256)             131328    ['batch_normalization_17[0][0]
#                                                                     ']
#
#  batch_normalization_18 (Ba  (None, 650, 256)             1024      ['PostGlobal256[0][0]']
#  tchNormalization)
#
#  PostGlobal128 (Conv1D)      (None, 650, 128)             32896     ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_19 (Ba  (None, 650, 128)             512       ['PostGlobal128[0][0]']
#  tchNormalization)
#
#  dropout (Dropout)           (None, 650, 128)             0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  SEG (Conv1D)                (None, 650, 1)               129       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5100822 (19.46 MB)
# Trainable params: 5069364 (19.34 MB)
# Non-trainable params: 31458 (122.88 KB)
# __________________________________________________________________________________________________
