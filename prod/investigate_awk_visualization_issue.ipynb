# %%
import numpy as np
from pathlib import Path

from visualizations.awk_visualization import visualize_truth
from load_from_root_file import load_from_root

# %%
root_file = Path("/Users/jhimmens/Library/CloudStorage/Dropbox/Work/TRIUMF/jetpointnet/prod/data/JZ4/user.jhimmens.41286680._000015.mltree.root")
root_file_ = Path("/Users/jhimmens/Library/CloudStorage/Dropbox/Work/TRIUMF/jetpointnet/prod/data/rho/user.jhimmens.41286604._000001.mltree.root")
geo_file = Path("/Users/jhimmens/Library/CloudStorage/Dropbox/Work/TRIUMF/jetpointnet/prod/data/rho_small.root")

arr = load_from_root(root_file, geo_file, debug=True)
arr
# Out:
# <Array [{runNumber: 410000, ...}, ..., {...}] type='20 * {runNumber: int64,...'>

# %%
arr[0]
# Out:
# <Record {runNumber: 410000, ...} type='{runNumber: int64, eventNumber: int6...'>

# %%
# %matplotlib ipympl
visualize_truth(arr[18], "views/observed_testing.png", figsize=(8,8))
# Out:
# pi+ - 0.63 GeV - 986 in layer HEC3 in color tab:blue
# pi+ - 4.96 GeV - 997 in layer HEC1 in color tab:orange
# pi- - 1.58 GeV - 968 in layer HEC3 in color tab:green
# p - 0.78 GeV - 1034 in layer HEC2 in color tab:red
# p~ - 6.14 GeV - 999 in layer EME3 in color tab:purple
# pi+ - 1.19 GeV - 1254 in layer HEC3 in color tab:brown
# pi+ - 21.82 GeV - 475 in layer TileExt2 in color tab:pink
# pi+ - 32.12 GeV - 868 in layer HEC0 in color tab:gray
# pi- - 8.85 GeV - 476 in layer TileExt2 in color tab:olive
# pi- - 71.11 GeV - 162 in layer TileExt2 in color tab:cyan
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
